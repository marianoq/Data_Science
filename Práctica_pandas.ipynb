# %% [markdown]
# <a href="https://colab.research.google.com/github/marianoq/data_science/blob/main/Pr%C3%A1ctica_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Librería Pandas**

# %%
# Importar Pandas
import pandas as pd

# %%
# Crear una serie de numeros y hallar su media
numeros = pd.Series([1,2,3,5,67,35,235,62])
numeros.mean()
# Out:
# 51.25

# %%
# Hallar la suma
numeros.sum()
# Out:
# 410

# %%
# Crear una serie de colores diferentes
colores = pd.Series(['rojo', 'amarillo', 'verde'])
colores
# Out:
# 0        rojo
# 1    amarillo
# 2       verde
# dtype: object

# %%
# Otra serie con tipos de autos
tipos_autos = pd.Series(['sedan','SUV','Pick Up'])
tipos_autos
# Out:
# 0      sedan
# 1        SUV
# 2    Pick Up
# dtype: object

# %%
# Comninar las series de tipos de autos y colores, DATAFRAME
tabla_autos = pd.DataFrame({'Tipo de Auto':tipos_autos, 'Colores':colores})
tabla_autos
# Out:
#   Tipo de Auto   Colores
# 0        sedan      rojo
# 1          SUV  amarillo
# 2      Pick Up     verde

# %%
# Conectar a nuestro Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importar archivo ventas-autos.csv
ventas_autos = pd.read_csv('/content/drive/MyDrive/MarianoColab/Data/ventas-autos.csv')
ventas_autos
# Out:
#   Fabricante   Color  Kilometraje  Puertas Precio (USD)
# 0     Toyota  Blanco       150043        4    $4,000.00
# 1      Honda    Rojo        87899        4    $5,000.00
# 2     Toyota    Azul        32549        3    $7,000.00
# 3        BMW   Negro        11179        5   $22,000.00
# 4     Nissan  Blanco       213095        4    $3,500.00
# 5     Toyota    Rojo        99213        4    $4,500.00
# 6      Honda  Blanco        45698        4    $7,500.00
# 7      Honda  Blanco        54738        4    $7,000.00
# 8     Toyota  Blanco        60000        4    $6,250.00
# 9     Nissan    Rojo        31600        4    $9,700.00

# %%
# Exportar archivo como csv
ventas_autos.to_csv('/content/drive/MyDrive/MarianoColab/prueb_ventas-autos.csv')
